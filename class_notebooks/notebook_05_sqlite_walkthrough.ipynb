# %% [markdown]
# # SQLite

# %%
import pandas as pd
import sqlite3 as sql

#since we are looking at poems, we'll bump up the width of our columns
pd.set_option("display.max_colwidth", 250)

# %% [markdown]
# ### Creating a connection to the poetry_kids.db database
#  - tell python what database to connect to (`sql.connect( )`)
#  - create a cursor to allow passing queries directly to the database

# %%
conn = sql.connect('../data/poetry_kids.db')
cur = conn.cursor()

# %% [markdown]
# ### Checking what tables exist within a database
# - the cursor executes the SQL query passed to `.execute( )`
# - the results of your query are loaded to the cursor
# - the `fetchall()` method returns those results so you can store them in a variable

# %%
# Execute tells the cursor to run the query provided

cur.execute("SELECT name FROM sqlite_master WHERE type='table' ORDER BY name;")

# fetchall() allows us to see everything returned by our query, which we store in our 'available_tables' variable

available_tables = (cur.fetchall())

available_tables
# Out:
# [('author',),
#  ('emotion',),
#  ('gender',),
#  ('grade',),
#  ('poem',),
#  ('poem_emotion',)]

# %% [markdown]
# Let's compare this to the **entity relationship diagram** (ERD) for this database.
#
# ![ERD](assets/PoetryKids_erd.png)

# %% [markdown]
# ## Using Pandas to place results into a DataFrame
#
# We can SQL queries and convert the result to a _pandas_ DataFrame by using the `read_sql` method.
#
# When building SQL queries, it may be useful to write the query independently and save to variable. Multi-line queries can use triple quotes (''' ''') to keep it together as one string.
#
# For example, if we want to find the very short poems, we can use the following code.

# %%
query = '''
SELECT text
FROM poem
WHERE char_count < 20;
'''

pd.read_sql(query, conn)
# Out:
#                 text
# 0       hello friend
# 1                bye
# 2     i like chicken
# 3      star,  star,
# 4     lol life rules
# 5   ghosts use magic
# 6           i love u
# 7   dragons are cool
# 8   may you bee ears
# 9   the time is gone
# 10      lost got hot
# 11              love
# 12           j o s e
# 13      kindkindkind
# 14   bat hat kat fat
# 15   rest  in  peace
# 16  wow look at that
# 17        i like pie
# 18     s t e v e n s
# 19   bunnies areblue
# 20      hate b    =p

# %% [markdown]
# Let's now practice writing queries. Remember the process we can use:
#
#     a. decide what tables you need
#     b. (if you need to use more than one table) decide how to connect your tables
#     c. decide which columns to select
#     d. decide what (if any) filters you want to apply in your `WHERE` clause

# %% [markdown]
# First, let's find the text of all poems with the title "cats".

# %%
query = '''
SELECT title
FROM poem
WHERE title = 'cats'
ORDER BY title;
'''

pd.read_sql(query, conn)
# Out:
#    title
# 0   cats
# 1   cats
# 2   cats
# 3   cats
# 4   cats
# 5   cats
# 6   cats
# 7   cats
# 8   cats
# 9   cats
# 10  cats
# 11  cats
# 12  cats
# 13  cats

# %% [markdown]
# Now, let's see find the emotion_id associated with these poems. Keep the text of the poem, the poem_id, the emotion_id, and the intensity_percent.
#
# Sort by the poem_id as the same poem can appear multiple times.

# %%
query = '''
SELECT po.text,pe.poem_id,pe.emotion_id,pe.intensity_percent
FROM poem as po
LEFT JOIN poem_emotion as pe
ON po.id = pe.poem_id
WHERE po.title = 'cats'
ORDER BY pe.poem_id;
'''

pd.read_sql(query, conn)
# Out:
#                                                                                           text  \
# 0                i like cats look at those hats but never mind that i like cats cats cats cats
# 1                                   cats are cute  cats are cute  i llike cats  what about you
# 2                      cats are really cute  they cause a lot of trouble who cares i dont mind
# 3                               cats are meowing and laying under the oak playing with a mouse
# 4   i love cats when  they  make sounds like this meow meow cat are raelly cute when they meow
# 5                                                                  cats aer fun cats are gerat
# 6              furry ones,  black ones,  stript ones too every cat is different and so are you
# 7                                                                cute   awesome treats special
# 8                                  i am very fury i climb trees when i get scard and i go meow
# 9                                  i am very fury i climb trees when i get scard and i go meow
# 10                                 i am very fury i climb trees when i get scard and i go meow
# 11                                 i am very fury i climb trees when i get scard and i go meow
# 12   cats. . . cats. . . cats. . . you know them you love them cats. . . cats. . . cats. . . !
# 13                             cats can be fat.  to me some are mean.  or funny like a bunny.
# 14                fast and sleek quiet and meek meowing and scrathing  and doing mice catching
# 15                fast and sleek quiet and meek meowing and scrathing  and doing mice catching
# 16           fast and sleek  quiet and meek  moewing and scratching  and doing mice catching.
# 17           fast and sleek  quiet and meek  moewing and scratching  and doing mice catching.
# 18                 the cats sleep all day the cats live to sleep and eat the cats live to love
#
#     poem_id  emotion_id  intensity_percent
# 0       NaN         NaN                NaN
# 1       NaN         NaN                NaN
# 2       NaN         NaN                NaN
# 3       NaN         NaN                NaN
# 4    1948.0         4.0               83.0
# 5    4508.0         4.0               79.0
# 6    4866.0         3.0               28.0
# 7   10232.0         4.0               57.0
# 8   14527.0         1.0               92.0
# 9   14527.0         2.0               67.0
# 10  14527.0         3.0               41.0
# 11  14527.0         4.0               20.0
# 12  14699.0         4.0               83.0
# 13  23663.0         3.0               20.0
# 14  28169.0         3.0               11.0
# 15  28169.0         4.0               19.0
# 16  28171.0         3.0               11.0
# 17  28171.0         4.0               19.0
# 18  31423.0         4.0               55.0

# %% [markdown]
# Finally, let's modify the above query to show the emotion name instead of the emotion_id. This will require joining with another table.

# %%
query = '''
SELECT text,poem_id,emotion.name,intensity_percent
FROM poem_emotion
LEFT JOIN poem
ON poem_id = poem.id
LEFT JOIN emotion
ON poem_emotion.emotion_id = emotion.id
WHERE title ='cats'
ORDER BY poem_id;
'''

# %%
query = '''
SELECT po.text,pe.poem_id,emotion.name,pe.intensity_percent
FROM poem as po
LEFT JOIN poem_emotion as pe
ON po.id = pe.poem_id
LEFT JOIN emotion AS e
ON emotion_id = emotion.id
WHERE po.title = 'cats'
ORDER BY pe.poem_id;
'''


pd.read_sql(query, conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    2055         try:
# -> 2056             cur.execute(*args, **kwargs)
#    2057             return cur
#
# OperationalError: no such column: emotion.name
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10924/1144577901.py in <module>
#      11
#      12
# ---> 13 pd.read_sql(query, conn)
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     600
#     601     if isinstance(pandas_sql, SQLiteDatabase):
# --> 602         return pandas_sql.read_query(
#     603             sql,
#     604             index_col=index_col,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#    2114
#    2115         args = _convert_params(sql, params)
# -> 2116         cursor = self.execute(*args)
#    2117         columns = [col_desc[0] for col_desc in cursor.description]
#    2118
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    2066
#    2067             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 2068             raise ex from exc
#    2069
#    2070     @staticmethod
#
# DatabaseError: Execution failed on sql '
# SELECT po.text,pe.poem_id,emotion.name,pe.intensity_percent
# FROM poem as po
# LEFT JOIN poem_emotion as pe
# ON po.id = pe.poem_id
# LEFT JOIN emotion AS e
# ON emotion_id = emotion.id
# WHERE po.title = 'cats'
# ORDER BY pe.poem_id;
# ': no such column: emotion.name

# %% [markdown]
# ## Best Practice - Close connections after use to prevent the tables from being locked

# %%
cur.close()
conn.close()
